# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("local-databricks") \
    .master("local[*]") \
    .getOrCreate()

df = spark.read.load(f"/Users/waltercaraza/Documents/Workplace/farmscgi/data/cows.parquet").show()
spark.read.load(f"/Users/waltercaraza/Documents/Workplace/farmscgi/data/measurements.parquet").show()
spark.read.load(f"/Users/waltercaraza/Documents/Workplace/farmscgi/data/sensors.parquet").show()
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/Documents/Workplace/farmscgi/venv/lib/python3.13/site-packages/py4j/clientserver.py:527, in ClientServerConnection.send_command(self, command)
#     526 try:
# --> 527     self.socket.sendall(command.encode("utf-8"))
#     528 except Exception as e:
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# File ~/Documents/Workplace/farmscgi/venv/lib/python3.13/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#
# ...
