# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("local-databricks") \
    .master("local[*]") \
    .getOrCreate()

spark.read.load(f"/Users/waltercaraza/Documents/Workplace/farms/data/cows.parquet").show()
spark.read.load(f"/Users/waltercaraza/Documents/Workplace/farms/data/measurements.parquet").show()
spark.read.load(f"/Users/waltercaraza/Documents/Workplace/farms/data/sensors.parquet").show()
# Out:
# +--------------------+-----------+----------+
# |                  id|       name| birthdate|
# +--------------------+-----------+----------+
# |c821a6b7-8dd0-4b4...| Lindsey #4|2020-01-09|
# |71122813-53a2-4a9...|   Linda #3|2019-09-09|
# |aea1439d-68a9-4e0...|  Sandra #3|2019-06-17|
# |668d213f-6b1d-4aa...| Kathryn #1|2020-04-17|
# |47a81ce1-859a-4db...|    Anna #1|2020-01-20|
# |85a129d2-0380-450...|   Carla #3|2021-09-22|
# |f7e0cdbc-b23e-483...| Heather #5|2020-07-18|
# |7203c734-bdb2-421...|    Mary #1|2019-03-08|
# |ef082efc-d476-4ca...|   Kelly #4|2020-04-06|
# |ade0509d-9078-415...| Destiny #1|2018-07-31|
# |3b2547ed-de1a-499...| Jessica #9|2021-08-26|
# |071f30bb-3b8a-445...|  Ashley #1|2020-05-27|
# |f5c0dc0e-aa4e-45a...|   Diane #8|2021-03-27|
# |edb28bf0-bf09-446...|Veronica #4|2018-07-25|
# |38c98773-d708-47a...|  Ashlee #9|2020-11-12|
# |b595d0d1-612b-4ae...| Adriana #7|2020-12-04|
# |478be788-f84c-48d...|Jennifer #4|2022-03-27|
# ...
